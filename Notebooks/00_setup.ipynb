# %% [markdown]
# # Análisis del ciclo de pedidos de Olist
#
# ## Descripción
#
# Proyecto de ingeniería de datos desarrollado en Databricks para analizar el ciclo completo de los pedidos de una plataforma brasileña de comercio electrónico.
#
# ## Problemática provisional
#
# Identificar los factores operativos, comerciales y geográficos relacionados con retrasos en las entregas y evaluaciones negativas de los clientes.
#
# ## Fuente de datos
#
# - Dataset: Brazilian E-Commerce Public Dataset by Olist
# - Fuente: Kaggle
# - Enlace: https://www.kaggle.com/datasets/olistbr/brazilian-ecommerce
# - Autor: Olist
# - Uso: Proyecto educativo y de portafolio
#
# ## Tecnologías
#
# Databricks, SQL, PySpark, Delta Lake, Git y GitHub.
#
# ## Arquitectura
#
# Raw → Bronze → Silver → Gold

# %%
ruta_principal="/Volumes/olist/default/raw/"

# %%
# %sql
Create schema if not exists olist.bronze
comment 'Esquema creado para los datos cargados desde los csv, conservando la estructura original.';

create schema if not exists olist.silver
comment 'Datos limpios, tipados, deduplicados y validados';

create schema if not exists olist.gold
comment 'Informacion preparada para responder la problematica del proyecto'
